# %%
import pandas as pd

# Read the CSV file
file_path = 'assign.csv'
df = pd.read_csv(file_path)

# Convert 'Time' and 'Time Out' columns to datetime type
df['Time'] = pd.to_datetime(df['Time'], format='%m/%d/%Y %I:%M %p', errors='coerce')
df['Time Out'] = pd.to_datetime(df['Time Out'], format='%m/%d/%Y %I:%M %p', errors='coerce')

# Sort DataFrame by 'Employee Name' and 'Time'
df = df.sort_values(by=['Employee Name', 'Time'])

# %%
# Part a: Employees who have worked for 7 consecutive days
def analyze_consecutive_days(data_frame):
    # Iterate through each employee
    for name, group in data_frame.groupby('Employee Name'):
        consecutive_days = group['Time'].diff().dt.days == 1

        if any(consecutive_days):
            print(f"{name} has worked for 7 consecutive days.")

# %%
# Part b: Employees who have less than 10 hours between shifts but greater than 1 hour
def analyze_shift_gaps(data_frame):
    # Iterate through each employee
    for name, group in data_frame.groupby('Employee Name'):
        less_than_10_hours = (group['Time'].diff().dt.total_seconds() / 3600 < 10) & (group['Time'].diff().dt.total_seconds() / 3600 > 1)

        if any(less_than_10_hours):
            print(f"{name} has less than 10 hours between shifts but greater than 1 hour.")

# %%
# Part c: Employees who have worked for more than 14 hours in a single shift
def analyze_long_shifts(data_frame):
    # Iterate through each employee
    for name, group in data_frame.groupby('Employee Name'):
        # Check if both 'Time' and 'Time Out' are present for the employee
        if 'Time Out' in group.columns and 'Time' in group.columns:
            # Check if there are at least two records for the employee
            if len(group) >= 2:
                more_than_14_hours = (group['Time Out'] - group['Time']).dt.total_seconds() / 3600 > 14

                if any(more_than_14_hours):
                    print(f"{name} has worked for more than 14 hours in a single shift.")

# %%
# Example usage
analyze_consecutive_days(df)
analyze_shift_gaps(df)
analyze_long_shifts(df)
# Out:
# AXcEcer, ECar JesAs has worked for 7 consecutive days.
# AXvarez, Edgar has worked for 7 consecutive days.
# ArCeWMa FXEres, JEWaMhaW has worked for 7 consecutive days.
# ArEsMigAi, AXexaWder has worked for 7 consecutive days.
# ArevaXE, JEse has worked for 7 consecutive days.
# Arias, FeXipe has worked for 7 consecutive days.
# ArrAMia, AXexis ArMArE has worked for 7 consecutive days.
# CAevas ZavaXa, JErge XAis has worked for 7 consecutive days.
# CEMMa, Jessica has worked for 7 consecutive days.
# CErMes, DEAgXas Farid has worked for 7 consecutive days.
# CEreira Jr, JEse has worked for 7 consecutive days.
# CaXdEWadE, AXfEWsE has worked for 7 consecutive days.
# CaraGiXXa, AWMhEWy has worked for 7 consecutive days.
# Caxies, MerreXX has worked for 7 consecutive days.
# CeciWa, SiXvesMre Jr has worked for 7 consecutive days.
# CercadE, CrisMiaW has worked for 7 consecutive days.
# CercadE, SaAX has worked for 7 consecutive days.
# CesiWa CEreWE, KeviW FaGiaW has worked for 7 consecutive days.
# ChaCErE, HEXger CarMiWez has worked for 7 consecutive days.
# CiGriaW DeXgadE, EXeWa S has worked for 7 consecutive days.
# DECiWgAez AviWa, CigAeX AWgeX has worked for 7 consecutive days.
# De XEs SaWMEs, JEseph XAis has worked for 7 consecutive days.
# DeXgadiXXE REdarMe, ChrisMiaW S has worked for 7 consecutive days.
# DiWh, DaA has worked for 7 consecutive days.
# Diaz GaXvez, RicardE JEsAe has worked for 7 consecutive days.
# EXivares, FeXCaW has worked for 7 consecutive days.
# ErEpeza, JEvaW has worked for 7 consecutive days.
# ErEzcE, SaAX has worked for 7 consecutive days.
# EsMrada, JEse FeXix has worked for 7 consecutive days.
# FaGiaW CiraWda, JEse has worked for 7 consecutive days.
# FeXix, XeEWeX has worked for 7 consecutive days.
# GAMierrez, PedrE CigAeX has worked for 7 consecutive days.
# GAeWdia, JAaW CarXEs has worked for 7 consecutive days.
# GarWes, JAsMiW has worked for 7 consecutive days.
# GrACfieXd, CErWeXiAs has worked for 7 consecutive days.
# HEGGie ErMega, SeGasMiaW CichaeX has worked for 7 consecutive days.
# HerWaWdez SaWchez, AWdrew AWMhEWy has worked for 7 consecutive days.
# JerEWiCE CEraXes, CarXEs D has worked for 7 consecutive days.
# MAake, CasiaWE has worked for 7 consecutive days.
# MAcker, CichaeX has worked for 7 consecutive days.
# MaXeGi, ACirCasEAd has worked for 7 consecutive days.
# MraW, WiXXiaC Ha has worked for 7 consecutive days.
# PaXaciE, JEWaMhaW has worked for 7 consecutive days.
# PayaW, DaWieX has worked for 7 consecutive days.
# Perez, EdwiW JiCeWez has worked for 7 consecutive days.
# PerkiWs, MarraWce has worked for 7 consecutive days.
# RAvaXcaGa GaWAeXEs, DaWieX JesAs has worked for 7 consecutive days.
# REdrigAez, GraWdEW AWgeX has worked for 7 consecutive days.
# REdrigAez, PedrE has worked for 7 consecutive days.
# REdrigAez, XAis has worked for 7 consecutive days.
# RaCEs HerWaWdez, AdieX ECar has worked for 7 consecutive days.
# SMrickXaWd, REdWey EAgeWe has worked for 7 consecutive days.
# SaWchez PaCpXEWa, CrisMiaW AXGerM has worked for 7 consecutive days.
# SavaWg, JEhW has worked for 7 consecutive days.
# SiWgXeMEW, REger has worked for 7 consecutive days.
# SiWgh, CaWpreeM has worked for 7 consecutive days.
# SiWgh, JaspreeM has worked for 7 consecutive days.
# Sparks, KeWWeMh has worked for 7 consecutive days.
# VasqAez, AXfredE has worked for 7 consecutive days.
# VasqAez, JEhW SeGasMiaW has worked for 7 consecutive days.
# ViXXa, AXfredE AieXXE has worked for 7 consecutive days.
# WiXXiaCs, MyrreXX has worked for 7 consecutive days.
# XEpez WAWez, XAis has worked for 7 consecutive days.
# XariEs XaWdaverde, XAis ErWesME has worked for 7 consecutive days.
# XariEs, Cesar GiEvaWWi has worked for 7 consecutive days.
# Xee, XaCar has worked for 7 consecutive days.
# XiWW, JAsMiW has worked for 7 consecutive days.
# ZaCEra, Edward has worked for 7 consecutive days.
# AGeX, WaMhaW REGerM PeWa has less than 10 hours between shifts but greater than 1 hour.
# AXcEcer, ECar JesAs has less than 10 hours between shifts but greater than 1 hour.
# AXvarez, Edgar has less than 10 hours between shifts but greater than 1 hour.
# ArCeWMa FXEres, JEWaMhaW has less than 10 hours between shifts but greater than 1 hour.
# ArEsMigAi, AXexaWder has less than 10 hours between shifts but greater than 1 hour.
# ArevaXE, JEse has less than 10 hours between shifts but greater than 1 hour.
# Arias, FeXipe has less than 10 hours between shifts but greater than 1 hour.
# ArrAMia, AXexis ArMArE has less than 10 hours between shifts but greater than 1 hour.
# CAevas ZavaXa, JErge XAis has less than 10 hours between shifts but greater than 1 hour.
# CEMMa, Jessica has less than 10 hours between shifts but greater than 1 hour.
# CErMes, DEAgXas Farid has less than 10 hours between shifts but greater than 1 hour.
# CEreira Jr, JEse has less than 10 hours between shifts but greater than 1 hour.
# CaMXEck, CEhaCCed has less than 10 hours between shifts but greater than 1 hour.
# CaMaXaWE, CeghaW has less than 10 hours between shifts but greater than 1 hour.
# CaXdEWadE, AXfEWsE has less than 10 hours between shifts but greater than 1 hour.
# CarMer, XyWWeXX DejAaW Jr has less than 10 hours between shifts but greater than 1 hour.
# CaraGiXXa, AWMhEWy has less than 10 hours between shifts but greater than 1 hour.
# Caxies, MerreXX has less than 10 hours between shifts but greater than 1 hour.
# CcRAWWeX, REWaXd Xee has less than 10 hours between shifts but greater than 1 hour.
# CeWdEza, Erik has less than 10 hours between shifts but greater than 1 hour.
# CeciWa, SiXvesMre Jr has less than 10 hours between shifts but greater than 1 hour.
# CercadE, CrisMiaW has less than 10 hours between shifts but greater than 1 hour.
# CercadE, SaAX has less than 10 hours between shifts but greater than 1 hour.
# CesiWa CEreWE, KeviW FaGiaW has less than 10 hours between shifts but greater than 1 hour.
# ChaCErE, HEXger CarMiWez has less than 10 hours between shifts but greater than 1 hour.
# CharXes, EGadiah SEraccE Jr has less than 10 hours between shifts but greater than 1 hour.
# CiGriaW DeXgadE, EXeWa S has less than 10 hours between shifts but greater than 1 hour.
# DECiWgAez AviWa, CigAeX AWgeX has less than 10 hours between shifts but greater than 1 hour.
# De XEs SaWMEs, JEseph XAis has less than 10 hours between shifts but greater than 1 hour.
# De Xa Cerda, IgWaciE has less than 10 hours between shifts but greater than 1 hour.
# DeXgadiXXE REdarMe, ChrisMiaW S has less than 10 hours between shifts but greater than 1 hour.
# DiWh, DaA has less than 10 hours between shifts but greater than 1 hour.
# DiXXard, JEwaWW Cedric has less than 10 hours between shifts but greater than 1 hour.
# Diaz GaXvez, RicardE JEsAe has less than 10 hours between shifts but greater than 1 hour.
# EXivares, FeXCaW has less than 10 hours between shifts but greater than 1 hour.
# EasMCaW, CichaeX has less than 10 hours between shifts but greater than 1 hour.
# ErEpeza, JEvaW has less than 10 hours between shifts but greater than 1 hour.
# ErEzcE, SaAX has less than 10 hours between shifts but greater than 1 hour.
# ErMiz, AGigaiX has less than 10 hours between shifts but greater than 1 hour.
# EsMrada, JEse FeXix has less than 10 hours between shifts but greater than 1 hour.
# FaGiaW CiraWda, JEse has less than 10 hours between shifts but greater than 1 hour.
# FeXix, XeEWeX has less than 10 hours between shifts but greater than 1 hour.
# GAMierrez, PedrE CigAeX has less than 10 hours between shifts but greater than 1 hour.
# GAeWdia, JAaW CarXEs has less than 10 hours between shifts but greater than 1 hour.
# GaWks, GryaW has less than 10 hours between shifts but greater than 1 hour.
# GaXCes, EXias XEpez has less than 10 hours between shifts but greater than 1 hour.
# GarWes, JAsMiW has less than 10 hours between shifts but greater than 1 hour.
# GrACfieXd, CErWeXiAs has less than 10 hours between shifts but greater than 1 hour.
# HAWMer, ViWceWM De PaAX has less than 10 hours between shifts but greater than 1 hour.
# HEGGie ErMega, SeGasMiaW CichaeX has less than 10 hours between shifts but greater than 1 hour.
# HaCiXMEW, DeaWMe DevEW has less than 10 hours between shifts but greater than 1 hour.
# HerCEsiXXE, PedrE has less than 10 hours between shifts but greater than 1 hour.
# HerWaWdez SaWchez, AWdrew AWMhEWy has less than 10 hours between shifts but greater than 1 hour.
# IWGEAa, JeffersEW has less than 10 hours between shifts but greater than 1 hour.
# JerEWiCE CEraXes, CarXEs D has less than 10 hours between shifts but greater than 1 hour.
# MAake, CasiaWE has less than 10 hours between shifts but greater than 1 hour.
# MAcker, CichaeX has less than 10 hours between shifts but greater than 1 hour.
# MaXeGi, ACirCasEAd has less than 10 hours between shifts but greater than 1 hour.
# Merrazas, GriaW has less than 10 hours between shifts but greater than 1 hour.
# MraW, WiXXiaC Ha has less than 10 hours between shifts but greater than 1 hour.
# PaAXE, KyXe has less than 10 hours between shifts but greater than 1 hour.
# PaXaciE, JEWaMhaW has less than 10 hours between shifts but greater than 1 hour.
# PayaW, DaWieX has less than 10 hours between shifts but greater than 1 hour.
# Perez, EdwiW JiCeWez has less than 10 hours between shifts but greater than 1 hour.
# PerkiWs, MarraWce has less than 10 hours between shifts but greater than 1 hour.
# RAvaXcaGa GaWAeXEs, DaWieX JesAs has less than 10 hours between shifts but greater than 1 hour.
# RECerE, SergiE has less than 10 hours between shifts but greater than 1 hour.
# REdrigAez, AXexis GAMierrez has less than 10 hours between shifts but greater than 1 hour.
# REdrigAez, GraWdEW AWgeX has less than 10 hours between shifts but greater than 1 hour.
# REdrigAez, PedrE has less than 10 hours between shifts but greater than 1 hour.
# REdrigAez, XAis has less than 10 hours between shifts but greater than 1 hour.
# REsaXiaWE, XAis has less than 10 hours between shifts but greater than 1 hour.
# RaCEs HerWaWdez, AdieX ECar has less than 10 hours between shifts but greater than 1 hour.
# Rivera AXcaWMar, GrayaW has less than 10 hours between shifts but greater than 1 hour.
# SMrickXaWd, REdWey EAgeWe has less than 10 hours between shifts but greater than 1 hour.
# SaWchez PaCpXEWa, CrisMiaW AXGerM has less than 10 hours between shifts but greater than 1 hour.
# SaWchez, ArWAXfE has less than 10 hours between shifts but greater than 1 hour.
# SavaWg, JEhW has less than 10 hours between shifts but greater than 1 hour.
# SiWgXeMEW, REger has less than 10 hours between shifts but greater than 1 hour.
# SiWgh, CaWpreeM has less than 10 hours between shifts but greater than 1 hour.
# SiWgh, JaspreeM has less than 10 hours between shifts but greater than 1 hour.
# SiWgh, MarAWpreeM has less than 10 hours between shifts but greater than 1 hour.
# Sparks, KeWWeMh has less than 10 hours between shifts but greater than 1 hour.
# VaXderraCa CasMiXXE, Escar FaGiaW has less than 10 hours between shifts but greater than 1 hour.
# VasqAez, AXfredE has less than 10 hours between shifts but greater than 1 hour.
# VasqAez, JEhW SeGasMiaW has less than 10 hours between shifts but greater than 1 hour.
# ViXXa, AXfredE AieXXE has less than 10 hours between shifts but greater than 1 hour.
# WgAyeW, RayCEWd has less than 10 hours between shifts but greater than 1 hour.
# WiXXiaCs, MyrreXX has less than 10 hours between shifts but greater than 1 hour.
# XEpez WAWez, XAis has less than 10 hours between shifts but greater than 1 hour.
# XariEs XaWdaverde, XAis ErWesME has less than 10 hours between shifts but greater than 1 hour.
# XariEs, Cesar GiEvaWWi has less than 10 hours between shifts but greater than 1 hour.
# Xee, XaCar has less than 10 hours between shifts but greater than 1 hour.
# XiWW, JAsMiW has less than 10 hours between shifts but greater than 1 hour.
# ZaCEra, CigAeX has less than 10 hours between shifts but greater than 1 hour.
# ZaCEra, Edward has less than 10 hours between shifts but greater than 1 hour.
# DeXgadiXXE REdarMe, ChrisMiaW S has worked for more than 14 hours in a single shift.
